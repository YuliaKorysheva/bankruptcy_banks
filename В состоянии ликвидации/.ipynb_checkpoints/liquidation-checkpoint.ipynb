# %%
import pandas as pd
import os

# %%
df = pd.read_csv('1(2012).csv', header=2, engine='python', sep=';')
df.head()
# Out:
#    №                   Наименование  Регистрационный номер  \
# 0  1           ГАГАРИНСКИЙ (АО), КБ                  606.0
# 1  2  УРАЛЬСКИЙ ТРАСТОВЫЙ БАНК, ОАО                 2523.0
# 2  3                БАНК СБРР (ООО)                 1284.0
# 3  4               СИБЭС (АО), БАНК                  208.0
# 4  5    (ОАО УДМУРТИНВЕСТСТРОЙБАНК)                 2447.0
#
#                                  Наименование полное  \
# 0  КОММЕРЧЕСКИЙ БАНК "ГАГАРИНСКИЙ" (АКЦИОНЕРНОЕ О...
# 1  ОТКРЫТОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "УРАЛЬСКИЙ ТРАСТ...
# 2  СИБИРСКИЙ БАНК РЕКОНСТРУКЦИИ И РАЗВИТИЯ (ОБЩЕС...
# 3                БАНК "СИБЭС" (АКЦИОНЕРНОЕ ОБЩЕСТВО)
# 4  АКЦИОНЕРНЫЙ КОММЕРЧЕСКИЙ УДМУРТСКИЙ ИНВЕСТИЦИО...
#
#                             Адрес (место нахождения)  \
# 0       119361, г. Москва, пер. Очаковский 2-Й, д. 7
# 1  426008, Удмуртская респ, г. Ижевск, ул. Пушкин...
# 2  625003, Тюменская обл., г. Тюмень, ул. Клары Ц...
# 3  644007, Омская обл., г. Омск, ул. Рабиновича, ...
# 4  426008, Удмуртская респ, г. Ижевск, ул. Пушкин...
#
#                Руководитель ФИО Дата регистрации Возраст банка  \
# 0  Хализев Александр Викторович       26.10.1990          28,0
# 1   Столбов Василий Анатольевич       05.10.1993          25,5
# 2     Сергеев Андрей Николаевич       25.12.1990          28,0
# 3      Кузнецов Евгений Юрьевич       05.10.1998          20,5
# 4   Столбов Василий Анатольевич       03.08.1993          25,5
#
#    Дата ликвидации         Статус                 ...                   \
# 0              NaN  Ликвидируется                 ...
# 1              NaN  Ликвидируется                 ...
# 2              NaN  Ликвидируется                 ...
# 3              NaN  Ликвидируется                 ...
# 4              NaN  Ликвидируется                 ...
#
#    2012 - 4мес., Учтённые векселя, RUB 2012 - 5мес., Учтённые векселя, RUB  \
# 0                                    0                                   0
# 1                           73 100 000                                   0
# 2                                    0                                   0
# 3                           78 801 000                          83 336 000
# 4                                    0                                   0
#
#   2012 - 6мес., Учтённые векселя, RUB 2012 - 7мес., Учтённые векселя, RUB  \
# 0                                   0                                   0
# 1                                   0                                   0
# 2                                   0                                   0
# 3                          30 881 000                          23 352 000
# 4                                   0                                   0
#
#   2012 - 8мес., Учтённые векселя, RUB  2012 - 9мес., Учтённые векселя, RUB  \
# 0                                   0                                    0
# 1                                   0                                    0
# 2                                   0                                    0
# 3                          20 932 000                           90 164 000
# 4                                   0                                    0
#
#   2012 - 10мес., Учтённые векселя, RUB  2012 - 11мес., Учтённые векселя, RUB  \
# 0                                    0                                     0
# 1                                    0                                     0
# 2                                    0                                     0
# 3                           86 070 000                            55 533 000
# 4                                    0                                     0
#
#    2012 - 12мес., Учтённые векселя, RUB  2013 - 1мес., Учтённые векселя, RUB
# 0                                     0                                    0
# 1                                     0                                  NaN
# 2                                     0                                    0
# 3                           141 668 000                          151 415 000
# 4                                     0                                  NaN
#
# [5 rows x 137 columns]

# %%
def get_df_in_folder(base_path):
    first_file = base_path + '/' + list(os.walk(base_path))[0][2][0]
    df = pd.read_csv(first_file, header=2, engine='python', sep=';', skipfooter=2)


    for file in list(os.walk(base_path))[0][2][1:]:
        if file.endswith('.csv'):
            df2 = pd.read_csv(base_path + '/' + file, header=2, engine='python', sep=';', skipfooter=2)

            df = df.join(df2, how='right', rsuffix='_right')
            for col in list(df):
                if '_right' in col:
                    del df[col]
    return df

# %%
df = get_df_in_folder('.')

# %%
df.to_csv('liquidation.csv', sep=';')

# %%
df.shape
# Out:
# (341, 2201)
